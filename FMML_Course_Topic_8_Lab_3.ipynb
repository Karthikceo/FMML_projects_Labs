# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikceo/FMML_projects_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 07:29:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   149MB/s    in 0.5s
#
# 2024-03-25 07:29:56 (149 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25145  1506.01398v1  A modified version of MRFFCM (Markov Random Fi...    cs
# 26934  1701.04224v2  The Aduio-visual Speech Recognition (AVSR) whi...    cs
# 4858   1606.01540v1  OpenAI Gym is a toolkit for reinforcement lear...    cs
# 6064   1606.07163v1  The Clock Drawing Test (CDT) is a rapid, inexp...  stat
# 5264    1208.3030v2  Fisher's linear discriminant analysis (FLDA) i...  stat
# ...             ...                                                ...   ...
# 22626  1703.01925v1  Deep generative models have been wildly succes...  stat
# 22628  1703.01968v3  Entropy Search (ES) and Predictive Entropy Sea...  stat
# 7048   1709.05849v1  This study presents a novel end-to-end archite...  stat
# 13246  cs/0312047v1  Websites of a particular class form increasing...    cs
# 22903  1710.05751v2  Time series forecasting is widely used in a mu...  stat
#
#                                                    title  year  \
# 25145  Recognition of Changes in SAR Images Based on ...  2015
# 26934  Auxiliary Multimodal LSTM for Audio-visual Spe...  2017
# 4858                                          OpenAI Gym  2016
# 6064   Interpretable Machine Learning Models for the ...  2016
# 5264   Asymptotic Generalization Bound of Fisher's Li...  2012
# ...                                                  ...   ...
# 22626                    Grammar Variational Autoencoder  2017
# 22628  Max-value Entropy Search for Efficient Bayesia...  2017
# 7048   Neonatal Seizure Detection using Convolutional...  2017
# 13246                         Mapping weblog communities  2003
# 22903    Time Series Prediction : Predicting Stock Price  2017
#
#                                                 keywords
# 25145  [detection, difference, generation, reduction,...
# 26934  [recognition, information, automatic, recognit...
# 4858   [reinforcement, collection, benchmark, interfa...
# 6064   [inexpensive, neuropsychological, screening, c...
# 5264   [discriminant, important, dimension, reduction...
# ...                                                  ...
# 22626  [generative, successful, representations, cont...
# 22628  [predictive, empirically, successful, optimiza...
# 7048   [architecture, hierarchical, representations, ...
# 13246  [particular, increasingly, understand, visuali...
# 22903  [forecasting, multitude, martingale, strongest...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25145    [detection, difference, generation, reduction,...
# 26934    [recognition, information, automatic, recognit...
# 4858     [reinforcement, collection, benchmark, interfa...
# 6064     [inexpensive, neuropsychological, screening, c...
# 5264     [discriminant, important, dimension, reduction...
#                                ...
# 32599    [classification, simultaneously, conventional,...
# 21156    [information, important, combining, imperfect,...
# 3530     [obtaining, livelihoods, developing, countries...
# 2818     [supervised, detecting, conditions, including,...
# 9686             [duplicate, framework, manufacturability]
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8979 words.
# Out of those 4547 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c883bf4-c57d-4fc2-a2c4-02ec69646d96" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c883bf4-c57d-4fc2-a2c4-02ec69646d96")) {                    Plotly.newPlot(                        "8c883bf4-c57d-4fc2-a2c4-02ec69646d96",                        [{"x":["difference","evaluation","classification","detection","generation","recognition","anisotropic","percentage","reduction","simulated","coefficient","automatically","architecture","preventing","lipreading","inference","important","cumbersome","application","automatic","multimodal","including","shortcomings","boltzmann","processing","projection","information","experiments","consideration","flexibility","extensibility","autoencoders","auxiliary","traditional","overfitting","collection","discusses","reinforcement","benchmark","performance","algorithms","components","interface","decisions","considerable","screening","developed","inexpensive","interpretability","substantially","outperformed","methodology","currently","automated","indicated","clinicians","cognitive","precision","interpretable","techniques","resulting","conditions","following","overcomes","population","classical","homoscedastic","proportionally","quantitative","limitations","discrimination","dimensionality","asymptotically","discriminant","statistical","asymptotic","description","dimension","generalization","applicable","assumption","structure","approaches","relational","different","unrelated","specificities","challenges","intelligence","implementing","investigated","discovering","researchers","correspondences","management","matchings","established","commercial","widespread","illustrate","uncertainty","originally","databases","artificial","introduce","clustering","challenging","introduction","implemented","hierarchical","comparing","objectively","especially","describes","disparate","available","constructs","properties","intensively","ensembles","algorithm","evaluated","regression","demonstrated","incorporate","foreground","occupancy","ambiguous","furthermore","estimation","remarkably","subtraction","interconnected","background","monocular","addresses","increases","solutions","outperforms","pedestrian","technique","explaining","explanations","communicated","behaviours","typically","violation","deviation","essential","contribute","explanation","expressed","communicating","machinery","identifying","naturalness","behaviour","transformations","abstraction","specifications","simplification","verification","susceptible","understudied","convolutional","communication","continues","implications","interpretation","applications","constrained","transforms","approximation","scientific","naturally","constraint","convergence","experimental","programming","approximate","transformed","scalability","sequences","discrepancy","quadratically","efficient","quadratic","parameter","efficiency","demonstrate","relations","extensive","alignments","particular","instances","ontologies","alignment","probabilistic","annotator","electronic"],"y":[59,250,517,317,177,366,8,19,117,58,27,187,263,8,3,213,350,10,242,198,37,234,12,17,309,48,692,615,34,43,2,26,24,159,28,69,20,112,227,936,597,111,23,44,42,13,195,10,9,34,21,74,59,108,8,6,52,83,33,364,146,119,85,7,54,120,0,4,76,53,20,59,18,20,160,16,45,64,116,43,67,338,452,25,706,2,2,124,92,19,48,26,71,14,53,2,50,28,20,72,79,15,46,131,335,140,253,31,105,101,84,2,125,79,7,312,15,226,3,11,816,145,133,111,67,18,4,24,154,201,10,7,6,80,19,64,72,129,282,9,255,13,13,4,11,107,7,10,71,21,13,43,3,3,87,5,30,44,22,12,6,37,5,4,376,57,6,20,67,434,59,19,114,39,61,89,126,375,106,132,22,40,89,16,2,409,31,121,185,584,92,177,8,255,91,29,43,161,10,21],"type":"bar"},{"x":["difference","evaluation","classification","detectio ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4547,), (4547, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.48826291079812206);'>Detection</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.4120734908136482);'>Effective</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.653846153846154);'>Extraction</span> <br/><br/><span style=''>There</span> <span style=''>is</span> <span style=''>an</span> <span style=''>abundant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>on</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.48826291079812206);'>detection</span> <span style=''>due</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style=''>many</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>Since</span> <span style=''>Viola</span> <span style=''>and</span> <span style=''>Jones</span> <span style=''>proposed</span> <span style=''>the</span> <span style=''>first</span> <span style=''>real</span> <span style=''>time</span> <span style=''>AdaBoost</span> <span style=''>based</span> <span style=''>face</span> <span style=''>detector</span> <span style=''>Haar</span> <span style=''>like</span> <span style=''>features</span> <span style=''>have</span> <span style=''>been</span> <span style=''>adopted</span> <span style=''>as</span> <span style=''>the</span> <span style=''>method</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>for</span> <span style=''>frontal</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.48826291079812206);'>detection</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>simple</span> <span style=''>features</span> <span style=''>other</span> <span style=''>than</span> <span style=''>Haar</span> <span style=''>like</span> <span style=''>features</span> <span style=''>can</span> <span style=''>also</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>for</span> <span style=''>training</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.4120734908136482);'>effective</span> <span style=''>face</span> <span style=''>detector</span> <span style=''>Since</span> <span style=''>single</span> <span style=''>feature</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.4507042253521127);'>discriminative</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>separate</span> <span style=''>faces</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>non</span> <span style=''>faces</span> <span style=''>we</span> <span style=''>further</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>our</span> <span style=''>simple</span> <span style=''>features</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>feature</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>occurrences</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style=''>proposed</span> <span style=''>features</span> <span style=''>yield</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Lévy</span> <span style=''>Process</span> <span style=''>Priors</span> <span style=''>for</span> <span style=''>Spectral</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>are</span> <span style=''>rich</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>function</span> <span style=''>When</span> <span style=''>used</span> <span style=''>for</span> <span style=''>long</span> <span style=''>range</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>It</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>critical</span> <span style=''>to</span> <span style=''>account</span> <span style=''>for</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>kernels</span> <span style=''>formed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>a</span> <span style=''>spectral</span> <span style=''>mixture</span> <span style=''>density</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Levy</span> <span style=''>process</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>has</span> <span style=''>support</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>popular</span> <span style=''>RBF</span> <span style=''>periodic</span> <span style=''>and</span> <span style=''>Matern</span> <span style=''>kernels</span> <span style=''>combined</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductive</span> <span style=''>biases</span> <span style=''>which</span> <span style=''>enable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>and</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>learning</span> <span style=''>long</span> <span style=''>range</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>and</span> <span style=''>state</span> <span style=''>of</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.5856573705179282);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.31840000000000007);'>Inference</span> <span style=''>and</span> <span style=''>the</span> <span style=''>QMR</span> <span style=''>DT</span> <span style=''>Network</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5856573705179282);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.31840000000000007);'>inference</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.5856573705179282);'>Variational</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(255, 0, 0, 0.33928571428571425);'>procedures</span> <span style=''>that</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.45038167938931295);'>approximations</span> <span style=''>to</span> <span style=''>marginal</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>They</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternatives</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.31840000000000007);'>inference</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.39107611548556426);'>stochastic</span> <span style=''>sampling</span> <span style=''>or</span> <span style=''>search</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5856573705179282);'>variational</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diagnostic</span> <span style='background-color:rgba(255, 0, 0, 0.31840000000000007);'>inference</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Quick</span> <span style=''>Medical</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Reference</span> <span style=''>(QMR)</span> <span style=''>network</span> <span style=''>The</span> <span style=''>QMR</span> <span style=''>network</span> <span style=''>is</span> <span style=''>a</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3375000000000001);'>graphical</span> <span style=''>model</span> <span style=''>built</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.32489451476793263);'>statistical</span> <span style=''>and</span> <span style=''>expert</span> <span style='background-color:rgba(0, 255, 0, 0.36594911937377705);'>knowledge</span> <span style=''>Exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.31840000000000007);'>inference</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>infeasible</span> <span style=''>in ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Directional</span> <span style=''>Decision</span> <span style=''>Lists</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>family</span> <span style=''>of</span> <span style=''>decision</span> <span style=''>lists</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>models</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>in</span> <span style=''>a</span> <span style=''>greedy</span> <span style=''>manner</span> <span style=''>The</span> <span style=''>defining</span> <span style=''>property</span> <span style=''>is</span> <span style=''>that</span> <span style=''>all</span> <span style=''>rules</span> <span style=''>are</span> <span style=''>oriented</span> <span style=''>in</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Particular</span> <span style=''>examples</span> <span style=''>of</span> <span style=''>this</span> <span style=''>family</span> <span style=''>are</span> <span style=''>decision</span> <span style=''>lists</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>monotonically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreasing</span> <span style=''>(or</span> <span style=''>increasing)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>confirm</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>family</span> <span style=''>is</span> <span style=''>easier</span> <span style=''>to</span> <span style=''>train</span> <span style=''>than</span> <span style=''>general</span> <span style=''>decision</span> <span style=''>lists</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exemplify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>usability</span> <span style=''>of</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>problem</span> <span style=''>symptoms</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manufacturing</span> <span style=''>process</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06680957484816005)
# 	processing (0.11039657020364416)
# 	experimental (0.1339764201500536)
# 	representation (0.12718828152911754)
# 	architecture (0.09396212933190425)
# 	detection (0.11325473383351196)
# 	different (0.2522329403358342)
# 	information (0.24723115398356557)
# 	recognition (0.1307609860664523)
# 	convolutional (0.13433369060378705)
#
# Some Statistics words are:
# 	variables (0.1294352823588206)
# 	stochastic (0.13243378310844578)
# 	estimation (0.17041479260369816)
# 	statistical (0.15692153923038482)
# 	algorithm (0.3933033483258371)
# 	theoretical (0.15792103948025987)
# 	distribution (0.1874062968515742)
# 	dimensional (0.18340829585207397)
# 	inference (0.20589705147426288)
# 	regression (0.1774112943528236)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d085a90-255c-417e-99c4-98d66b629d54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d085a90-255c-417e-99c4-98d66b629d54")) {                    Plotly.newPlot(                        "1d085a90-255c-417e-99c4-98d66b629d54",                        [{"x":["difference","evaluation","classification","detection","generation","recognition","anisotropic","percentage","reduction","simulated","coefficient","automatically","architecture","preventing","lipreading","inference","important","cumbersome","application","automatic","multimodal","including","shortcomings","boltzmann","processing","projection","information","experiments","consideration","flexibility","extensibility","autoencoders","auxiliary","traditional","overfitting","collection","discusses","reinforcement","benchmark","performance","algorithms","components","interface","decisions","considerable","screening","developed","inexpensive","interpretability","substantially","outperformed","methodology","currently","automated","indicated","clinicians","cognitive","precision","interpretable","techniques","resulting","conditions","following","overcomes","population","classical","homoscedastic","proportionally","quantitative","limitations","discrimination","dimensionality","asymptotically","discriminant","statistical","asymptotic","description","dimension","generalization","applicable","assumption","structure","approaches","relational","different","unrelated","specificities","challenges","intelligence","implementing","investigated","discovering","researchers","correspondences","management","matchings","established","commercial","widespread","illustrate","uncertainty","originally","databases","artificial","introduce","clustering","challenging","introduction","implemented","hierarchical","comparing","objectively","especially","describes","disparate","available","constructs","properties","intensively","ensembles","algorithm","evaluated","regression","demonstrated","incorporate","foreground","occupancy","ambiguous","furthermore","estimation","remarkably","subtraction","interconnected","background","monocular","addresses","increases","solutions","outperforms","pedestrian","technique","explaining","explanations","communicated","behaviours","typically","violation","deviation","essential","contribute","explanation","expressed","communicating","machinery","identifying","naturalness","behaviour","transformations","abstraction","specifications","simplification","verification","susceptible","understudied","convolutional","communication","continues","implications","interpretation","applications","constrained","transforms","approximation","scientific","naturally","constraint","convergence","experimental","programming","approximate","transformed","scalability","sequences","discrepancy","quadratically","efficient","quadratic","parameter","efficiency","demonstrate","relations","extensive","alignments","particular","instances","ontologies","alignment","probabilistic","annotator","electronic","guidelines","extraction","construction","concerning","knowledge","prevented","agreement","indicating","indicators","identified","reliability","controlling","explicitly","proposing","implicitly","summaries","annotators","annotation","foundation","annotated","annotations","developing","displayed","attributes","capturing","discharge","cardiovascular","assertions","preparing","distributed","representations","dimensional","explained","partitions","partition","variables","intuitive","reconstructions","partitioning","dynamically","translating","outperform","granularity","conventional","character","exploring","alleviated","vocabulary","empirical","disadvantages","granularities","difficult","involving","comparison ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	homoscedastic
# 	sequentialized
# 	straggler
# 	staleness
# 	integrators
# 	reconcile
# 	quadrature
# 	harnessed
# 	integrable
# 	timelines
# 	broadening
# 	mislabeled
# 	irregularly
# 	heteroscedastic
# 	confounders
# 	morgenstern
# 	unconfounded
# 	confounder
# 	saturation
# 	backfitting
# Some words which never appear in Statistics papers:
# 	preventing
# 	lipreading
# 	specificities
# 	monocular
# 	naturalness
# 	understudied
# 	displayed
# 	hallucination
# 	sentential
# 	undermines
# 	quadcopter
# 	concluded
# 	stakeholders
# 	centuries
# 	experimenters
# 	mastering
# 	retrained
# 	authentication
# 	handwritings
# 	psychological

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.073424101791807e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
